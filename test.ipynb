# %% [markdown]
# <a href="https://colab.research.google.com/github/nayandarekar/module1/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= 1
print(a)
# Out:
# 1
